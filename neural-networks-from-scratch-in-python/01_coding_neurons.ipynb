# %% [markdown]
# <a href="https://colab.research.google.com/github/rahiakela/deep-learning-research-and-practice/blob/main/neural-networks-from-scratch-in-python/01_coding_neurons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
import numpy as np

# %% [markdown]
# ## A Single Neuron

# %% [markdown]
# - When you initialize parameters in neural networks, our network will have weights initialized randomly, and biases set as zero to start.
# - Weights are one of the types of values that change inside the model during the training phase, along with biases that also change during training.
# - The values for weights and biases are what get “trained,” and they are what make a model actually work (or not work).

# %%
inputs = [1, 2, 3]
weights = [0.2 , 0.8 , - 0.5]
bias = 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
output = (inputs[0] * weights[0] + inputs[1] * weights[1] + inputs[2] * weights[2] + bias)
print(output)
# Out:
# 2.3

# %%
# for 4 inputs
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2 , 0.8 , - 0.5, 1.0]
bias = 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
output = (inputs[0] * weights[0] + inputs[1] * weights[1] + inputs[2] * weights[2] + inputs[3] * weights[3] + bias)
print(output)
# Out:
# 4.8

# %% [markdown]
# ## A Layer of Neurons

# %% [markdown]
# - Layers are nothing more than groups of neurons.
# - Each neuron in a layer takes exactly the same input — the input given to the layer, but contains its own set of weights and its own bias, producing its own unique output.
# - The layer’s output is a set of each of these outputs — one per each neuron.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inputs = [1.0, 2.0, 3.0, 2.5]

weights1 = [0.2 , 0.8 , - 0.5, 1.0]
weights2 = [0.5 , - 0.91 , 0.26 , - 0.5]
weights3 = [- 0.26 , - 0.27 , 0.17 , 0.87]

bias1 = 2
bias2 = 3
bias3 = 0.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
outputs = [
    # Neuron 1:
    inputs[0] * weights1[0] +
    inputs[1] * weights1[1] +
    inputs[2] * weights1[2] +
    inputs[3] * weights1[3] + bias1,

    # Neuron 2:
    inputs[0] * weights2[0] +
    inputs[1] * weights2[1] +
    inputs[2] * weights2[2] +
    inputs[3] * weights2[3] + bias2,

    # Neuron 3:
    inputs[0] * weights3[0] +
    inputs[1] * weights3[1] +
    inputs[2] * weights3[2] +
    inputs[3] * weights3[3] + bias3
]
print(outputs)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# Let's use a loop to scale and handle dynamically-sized inputs and layers.

# %%
inputs = [1.0, 2.0, 3.0, 2.5]

weights = [
    [0.2 , 0.8 , - 0.5, 1.0],
    [0.5 , - 0.91 , 0.26 , - 0.5],
    [- 0.26 , - 0.27 , 0.17 , 0.87]
]

bias = [2, 3, 0.5]

# Output of current layer
layer_outputs = []
# For each neuron
for neuron_weights, neuron_bias in zip(weights, bias):
  # Zeroed output of given neuron
  neuron_output = 0
  # For each input and weight to the neuron
  for n_input, weight in zip(inputs, neuron_weights):
    # Multiply this input by associated weight
    # and add to the neuron's output variable
    neuron_output += n_input * weight
  # Add bias
  neuron_output += neuron_bias
  # Put neuron's result to the layer's output list
  layer_outputs.append(neuron_output)

print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# ## Dot Product and Vector Addition

# %% [markdown]
# - When multiplying vectors, you either perform a dot product or a cross product.
# - A cross product results in a vector while a dot product results in a scalar (a single value/number).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = [1, 2, 3]
b = [2, 3, 4]

dot_product = a[0]*b[0] + a[1]*b[1] + a[2]*b[2]
print(dot_product)
# Out:
# 20

# %% [markdown]
# Let’s code for a single neuron using the dot product and the addition of the vectors with NumPy.

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2 , 0.8 , -0.5, 1.0]
bias = 2.0

outputs = np.dot(weights, inputs) + bias
print(outputs)
# Out:
# 4.8

# %% [markdown]
# Let’s code for a layer of neurons using the dot product and the addition of the vectors with NumPy.

# %%
inputs = [1.0, 2.0, 3.0, 2.5]

weights = [
    [0.2 , 0.8 , - 0.5, 1.0],
    [0.5 , - 0.91 , 0.26 , - 0.5],
    [- 0.26 , - 0.27 , 0.17 , 0.87]
]

bias = [2, 3, 0.5]

layer_outputs = np.dot(weights, inputs) + bias
print(layer_outputs)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# ## A Batch of Data

# %%
# a group of samples (inputs)
inputs = [
    [1.0, 2.0, 3.0, 2.5],
    [2.0, 5.0, -1.0, 2.0],
    [-1.5, 2.7, 3.3, -0.8]
]

weights = [
    [0.2 , 0.8 , - 0.5, 1.0],
    [0.5 , - 0.91 , 0.26 , - 0.5],
    [- 0.26 , - 0.27 , 0.17 , 0.87]
]

bias = [2.0, 3.0, 0.5]

layer_outputs = np.dot(inputs, np.array(weights).T) + bias
print(layer_outputs)
# Out:
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]
